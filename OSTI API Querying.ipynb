# %% [markdown]
# # Purpose
#
# This notebook is setup to query the [OSTI.gov](https://www.OSTI.gov) API for project records. The goals for the code located herein are:
#
# 1. Determine what fields are available for different records in OSTI
# 2. Design a DOE Solar Energy Technologies Office (SETO) query that only pulls that technology office's data
# 3. Build the query to work using an arbitrarily-large list of formatted project IDs, assuming the Solar Information Management System (SIMS) project code syntax as the input.
#     * **Note**: SIMS is an internal DOE system

# %% [markdown]
# # To Do
#
# 1. Get query text from Strategic Support that searches only for SETO projects
#     * This won't be critical long-term though, as SIMS should be able to generate a list of all Active projects that can be fed into the query
# 2. Figure out exactly what params are most useful using the [OSTI API docs](https://www.osti.gov/api/v1/docs).

# %%
#Query the API, mimicking the pre-made SS search URL as closely as possible
import requests

URL = "https://www.osti.gov/api/v1/records"

#sort by publication date, with the most current dates first (these can be future values)
    #and only return records that are for thing sponsored by the solar office, EE-4S
params = {'sort': 'publication_date desc', 'sponsor_org': 'EE-4S'}

r = requests.get(URL, params=params)

query_date = r.headers["Date"]
results_count = r.headers['X-Total-Count']

print(f"Query was successful: {r.status_code == requests.codes.ok}")
print(f"Query made on {query_date} returned {results_count} hits")
print(f"URL used was {r.url}")
# Out:
# Query was successful: True
# Query made on Wed, 27 Feb 2019 03:35:18 GMT returned 16252 hits
# URL used was https://www.osti.gov/api/v1/records?sort=publication_date+desc&sponsor_org=EE-4S

# %% [markdown]
# # Problems
#
# 1. Using [this search URL](https://www.osti.gov/search/sort:publication_date%20desc/sponsor-org:EE-4S#), I'm able to get results that are specific to the solar office (SETO = EE-4S) just fine. *But if I try to use the same parameters for the API call, I get nonsensical results*.
#     * If I try to sort by publication date without specifying a sort order, I don't see any really default ordering so I may as well have not done the sort in the first place
#     * If I try to specify the sort order by using the parameter order: desc, it fails. The API documentation is flawed in this way, because really what it wants you to do is **specify the sort order as part of the sort field specification**. In other words, instead of `{'sort': 'publication_date', 'order': 'desc'}`, it actually only works if you do `{'sort': 'publication_date desc'}`, even though the documentation says otherwise.
# 2. Regardless of the sorting issues, using sponsoring_org = EE-4S doesn't seem to be working as intended.

# %%
#Import the JSON query response into a DataFrame for cleaning
import pandas as pd
import numpy as np

df = pd.DataFrame.from_dict(r.json())
df
# Out:
#                        article_type  \
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# 5                              None
# 6                 Published Article
# 7                 Published Article
# 8                              None
# 9                              None
# 10                             None
# 11                             None
# 12                             None
# 13                             None
# 14                             None
# 15                             None
# 16                             None
# 17  Publisher's Accepted Manuscript
# 18  Publisher's Accepted Manuscript
# 19  Publisher's Accepted Manuscript
#
#                                               authors availability  \
# 0                  [Dong, Changgui, Sigrin, Benjamin]
# 1   [Skoryunov, R. V., Babanova, O. A., Soloninin,...
# 2   [Sulas, Dana B., Johnston, Steve (ORCID:000000...
# 3   [Cai, Can, Miller, David C., Tappan, Ian A., D...
# 4   [Monroe, Eric, Gladden, John, Albrecht, Karl O...
# 5                         [Neises, Ty, Turchi, Craig]
# 6   [Padgett, Elliot (ORCID:0000000190342335), Yar...
# 7   [Schuler, Tobias, Chowdhury, Anamika, Freiberg...
# 8   [Jain, Akshay Kumar [National Renewable Energy...
# 9   [Woodhouse, Michael A [National Renewable Ener...
# 10  [Kandt, Alicen J [National Renewable Energy La...
# 11  [Engel-Cox, Jill [National Renewable Energy La...
# 12  [Engel-Cox, Jill [National Renewable Energy La...
# 13  [Beiter, Philipp C [National Renewable Energy ...
# 14  [Moriarty, Patrick J [National Renewable Energ...
# 15  [OShaughnessy, Eric J [National Renewable Ener...
# 16  [Williams, Juliana [National Renewable Energy ...
# 17  [Yin, Wan-Jian [College of Energy, Soochow Ins...
# 18  [Mistry, Aashutosh N. [School of Mechanical En...
# 19  [Alvarado, Judith [Electrochemistry Branch, Se...
#
#    contributing_org country_publication  \
# 0                         United States
# 1                         United States
# 2                         United States
# 3                         United States
# 4                         United States
# 5                         United States
# 6                         United States
# 7                         United States
# 8                         United States
# 9                         United States
# 10                        United States
# 11                        United States
# 12                        United States
# 13                        United States
# 14                        United States
# 15                        United States
# 16                        United States
# 17                       United Kingdom
# 18                       United Kingdom
# 19                       United Kingdom
#
#                                           description  \
# 0   Distributed energy resources, such as rooftop ...
# 1   In order to study the dynamical properties of ...
# 2   We investigate the implications of using parti...
# 3   We developed a framework to predict and model ...
# 4   This work describes the first documented case ...
# 5   This analysis investigates the design, cost, a...
# 6
# 7
# 8   Distributed photovoltaic systems (DPV) can cau...
# 9   In this paper we provide an overview of the ac...
# 10  In 2018, NREL performed a demonstration of the...
# 11  Energy systems across the world are undergoing...
# 12  Energy systems in communities across the world...
# 13  This report analyzes the power purchase agreem...
# 14  The effects of wind turbine wakes within opera...
# 15  The New York City Mayor's Office of Sustainabi...
# 16  This report explores how public utility commis...
# 17  <p>Oxide perovskites and their derivatives are...
# 18  <p>\n The spatial coupling between the pore-sc...
# 19  <p>\n Breakthroughs in performance of Li/Cu wi...
#
#                       doe_contract_number                            doi  \
# 0                          AC36-08GO28308    10.1016/j.enpol.2019.02.017
# 1                          AC36-08GO28308  10.1016/j.jallcom.2018.12.162
# 2                          AC36-08GO28308   10.1016/j.solmat.2018.12.022
# 3                          AC36-08GO28308   10.1016/j.solmat.2018.11.024
# 4                          AC36-08GO28308     10.1016/j.fuel.2018.11.046
# 5                          AC36-08GO28308  10.1016/j.solener.2019.01.078
# 6               EE0007271; AC02-06CH11357           10.1149/2.0371904jes
# 7                          AC02-05CH11231           10.1149/2.0031907jes
# 8                          AC36-08GO28308
# 9                          AC36-08GO28308
# 10                         AC36-08GO28308
# 11                         AC36-08GO28308
# 12                         AC36-08GO28308
# 13                         AC36-08GO28308                10.2172/1495385
# 14                         AC36-08GO28308                10.2172/1495386
# 15                         AC36-08GO28308                10.2172/1495387
# 16                         AC36-08GO28308                10.2172/1495388
# 17                                                    10.1039/C8EE01574K
# 18                             CAEBAT III             10.1039/C8CP05109G
# 19  Battery500 Consortium; AC02-05CH11231             10.1039/C8EE02601G
#
#               entry_date                           format  ...  \
# 0   2019-02-25T05:00:00Z      Medium: X; Size: p. 100-110  ...
# 1   2019-01-23T05:00:00Z      Medium: X; Size: p. 913-918  ...
# 2   2019-01-23T05:00:00Z        Medium: X; Size: p. 81-87  ...
# 3   2019-01-08T05:00:00Z      Medium: X; Size: p. 486-492  ...
# 4   2019-02-07T05:00:00Z    Medium: X; Size: p. 1143-1148  ...
# 5   2019-02-25T05:00:00Z        Medium: X; Size: p. 27-36  ...
# 6   2019-02-25T05:00:00Z    Medium: X; Size: p. F198-F207  ...
# 7   2019-02-22T05:00:00Z  Medium: X; Size: p. F3020-F3031  ...
# 8   2019-02-26T05:00:00Z         Medium: ED; Size: 1.4 MB  ...
# 9   2019-02-26T05:00:00Z         Medium: ED; Size: 4.5 MB  ...
# 10  2019-02-26T05:00:00Z         Medium: ED; Size: 8.6 MB  ...
# 11  2019-02-25T05:00:00Z         Medium: ED; Size: 4.0 MB  ...
# 12  2019-02-25T05:00:00Z         Medium: ED; Size: 3.7 MB  ...
# 13  2019-02-26T05:00:00Z         Medium: ED; Size: 918 KB  ...
# 14  2019-02-26T05:00:00Z         Medium: ED; Size: 349 KB  ...
# 15  2019-02-26T05:00:00Z         Medium: ED; Size: 558 KB  ...
# 16  2019-02-26T05:00:00Z         Medium: ED; Size: 1.3 MB  ...
# 17  2019-02-15T05:00:00Z      Medium: X; Size: p. 442-462  ...
# 18  2019-02-15T05:00:00Z    Medium: X; Size: p. 3805-3813  ...
# 19  2019-02-15T05:00:00Z      Medium: X; Size: p. 780-794  ...
#
#                                                 links  osti_id  \
# 0   [{'rel': 'citation', 'href': 'https://www.osti...  1494980
# 1   [{'rel': 'citation', 'href': 'https://www.osti...  1491139
# 2   [{'rel': 'citation', 'href': 'https://www.osti...  1491141
# 3   [{'rel': 'citation', 'href': 'https://www.osti...  1489188
# 4   [{'rel': 'citation', 'href': 'https://www.osti...  1492507
# 5   [{'rel': 'citation', 'href': 'https://www.osti...  1494976
# 6   [{'rel': 'citation', 'href': 'https://www.osti...  1495620
# 7   [{'rel': 'citation', 'href': 'https://www.osti...  1495252
# 8   [{'rel': 'citation', 'href': 'https://www.osti...  1495718
# 9   [{'rel': 'citation', 'href': 'https://www.osti...  1495719
# 10  [{'rel': 'citation', 'href': 'https://www.osti...  1495720
# 11  [{'rel': 'citation', 'href': 'https://www.osti...  1495383
# 12  [{'rel': 'citation', 'href': 'https://www.osti...  1495384
# 13  [{'rel': 'citation', 'href': 'https://www.osti...  1495385
# 14  [{'rel': 'citation', 'href': 'https://www.osti...  1495386
# 15  [{'rel': 'citation', 'href': 'https://www.osti...  1495387
# 16  [{'rel': 'citation', 'href': 'https://www.osti...  1495388
# 17  [{'rel': 'citation', 'href': 'https://www.osti...  1465601
# 18  [{'rel': 'citation', 'href': 'https://www.osti...  1478674
# 19  [{'rel': 'citation', 'href': 'https://www.osti...  1493073
#
#         product_type      publication_date                         publisher  \
# 0    Journal Article  2019-06-01T04:00:00Z                          Elsevier
# 1    Journal Article  2019-04-01T04:00:00Z                          Elsevier
# 2    Journal Article  2019-04-01T04:00:00Z                          Elsevier
# 3    Journal Article  2019-03-01T05:00:00Z                          Elsevier
# 4    Journal Article  2019-03-01T05:00:00Z                          Elsevier
# 5    Journal Article  2019-03-01T05:00:00Z                          Elsevier
# 6    Journal Article  2019-02-21T05:00:00Z       The Electrochemical Society
# 7    Journal Article  2019-02-20T05:00:00Z       The Electrochemical Society
# 8         Conference  2019-02-15T05:00:00Z
# 9   Technical Report  2019-02-15T05:00:00Z
# 10  Technical Report  2019-02-15T05:00:00Z
# 11        Conference  2019-02-14T05:00:00Z
# 12        Conference  2019-02-14T05:00:00Z
# 13  Technical Report  2019-02-14T05:00:00Z
# 14  Technical Report  2019-02-14T05:00:00Z
# 15  Technical Report  2019-02-14T05:00:00Z
# 16  Technical Report  2019-02-14T05:00:00Z
# 17   Journal Article  2019-02-13T05:00:00Z  Royal Society of Chemistry (RSC)
# 18   Journal Article  2019-02-13T05:00:00Z  Royal Society of Chemistry (RSC)
# 19   Journal Article  2019-02-13T05:00:00Z  Royal Society of Chemistry (RSC)
#
#          report_number                                      research_orgs  \
# 0   NREL/JA-6A20-66020  [National Renewable Energy Lab. (NREL), Golden...
# 1   NREL/JA-5900-73081  [National Renewable Energy Lab. (NREL), Golden...
# 2   NREL/JA-5K00-71930  [National Renewable Energy Lab. (NREL), Golden...
# 3   NREL/JA-5K00-73005  [National Renewable Energy Lab. (NREL), Golden...
# 4   NREL/JA-5400-73186  [National Renewable Energy Lab. (NREL), Golden...
# 5   NREL/JA-5500-72674  [National Renewable Energy Lab. (NREL), Golden...
# 6                                                                      []
# 7                                                                      []
# 8   NREL/CP-5D00-72284  [National Renewable Energy Lab. (NREL), Golden...
# 9   NREL/TP-6A20-72134  [National Renewable Energy Lab. (NREL), Golden...
# 10  NREL/TP-7A40-72028  [National Renewable Energy Lab. (NREL), Golden...
# 11  NREL/PR-6A50-73118  [National Renewable Energy Lab. (NREL), Golden...
# 12  NREL/PR-6A50-73119  [National Renewable Energy Lab. (NREL), Golden...
# 13  NREL/TP-5000-72981  [National Renewable Energy Lab. (NREL), Golden...
# 14  NREL/TP-5000-73292  [National Renewable Energy Lab. (NREL), Golden...
# 15  NREL/TP-6A20-72186  [National Renewable Energy Lab. (NREL), Golden...
# 16  NREL/TP-6A20-72891  [National Renewable Energy Lab. (NREL), Golden...
# 17                                                                     []
# 18                                                                     []
# 19                                                                     []
#
#                                          sponsor_orgs  \
# 0   [USDOE Office of Energy Efficiency and Renewab...
# 1   [USDOE Office of Energy Efficiency and Renewab...
# 2   [USDOE Office of Energy Efficiency and Renewab...
# 3   [USDOE Office of Energy Efficiency and Renewab...
# 4   [USDOE Office of Energy Efficiency and Renewab...
# 5   [USDOE Office of Energy Efficiency and Renewab...
# 6   [USDOE Office of Energy Efficiency and Renewab...
# 7   [USDOE Office of Energy Efficiency and Renewab...
# 8   [USDOE Office of Energy Efficiency and Renewab...
# 9   [USDOE Office of Energy Efficiency and Renewab...
# 10  [USDOE Office of Energy Efficiency and Renewab...
# 11  [USDOE Office of Energy Efficiency and Renewab...
# 12  [USDOE Office of Energy Efficiency and Renewab...
# 13  [USDOE Office of Energy Efficiency and Renewab...
# 14  [USDOE Office of Energy Efficiency and Renewab...
# 15  [USDOE Office of Energy Efficiency and Renewab...
# 16  [USDOE Office of Energy Efficiency and Renewab...
# 17  [USDOE Office of Energy Efficiency and Renewab...
# 18  [USDOE Office of Energy Efficiency and Renewab...
# 19  [USDOE Office of Energy Efficiency and Renewab...
#
#                                              subjects  \
# 0   [14 SOLAR ENERGY, 29 ENERGY PLANNING, POLICY, ...
# 1   [36 MATERIALS SCIENCE, energy storage material...
# 2   [14 SOLAR ENERGY, 36 MATERIALS SCIENCE, silico...
# 3   [14 SOLAR ENERGY, 36 MATERIALS SCIENCE, accele...
# 4   [09 BIOMASS FUELS, 37 INORGANIC, ORGANIC, PHYS...
# 5   [14 SOLAR ENERGY, 47 OTHER INSTRUMENTATION, co...
# 6                                                  []
# 7                                                  []
# 8   [14 SOLAR ENERGY, 24 POWER TRANSMISSION AND DI...
# 9   [14 SOLAR ENERGY, 29 ENERGY PLANNING, POLICY, ...
# 10  [32 ENERGY CONSERVATION, CONSUMPTION, AND UTIL...
# 11  [29 ENERGY PLANNING, POLICY, AND ECONOMY, 54 E...
# 12  [29 ENERGY PLANNING, POLICY, AND ECONOMY, 54 E...
# 13  [17 WIND ENERGY, 29 ENERGY PLANNING, POLICY, A...
# 14  [17 WIND ENERGY, turbine, wind farm, energy, o...
# 15  [14 SOLAR ENERGY, 29 ENERGY PLANNING, POLICY, ...
# 16  [29 ENERGY PLANNING, POLICY, AND ECONOMY, publ...
# 17                                                 []
# 18                                                 []
# 19                                                 []
#
#                                                 title
# 0   Using Willingness to Pay to Forecast the Adopt...
# 1   Nuclear Magnetic Resonance Study of Anion and ...
# 2   Comparison of Photovoltaic Module Luminescence...
# 3   Framework for Predicting the Photodegradation ...
# 4   Discovery of novel octane hyperboosting phenom...
# 5   Supercritical Carbon Dioxide Power Cycle Desig...
# 6   Mitigation of PEM Fuel Cell Catalyst Degradati...
# 7   Fuel-Cell Catalyst-Layer Resistance via Hydrog...
# 8   Quasi-Static Times Series PV Hosting Capacity ...
# 9   Crystalline Silicon Photovoltaic Module Manufa...
# 10            Plug Load Management System Field Study
# 11  Clean Energy Technologies for Economic Transit...
# 12  Clean Energy Technologies for Economic Develop...
# 13  The Vineyard Wind Power Purchase Agreement: In...
# 14  Array Effects in Large Wind Farms: Cooperative...
# 15  Expanding Community Shared Solar in New York C...
# 16  Resourceful States: Addressing Energy Challeng...
# 17  Oxide perovskites, double perovskites and deri...
# 18  Probing spatial coupling of resistive modes in...
# 19  Bisalt ether electrolytes: a pathway towards l...
#
# [20 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 24 columns):
# article_type           5 non-null object
# authors                20 non-null object
# availability           20 non-null object
# contributing_org       20 non-null object
# country_publication    20 non-null object
# description            20 non-null object
# doe_contract_number    20 non-null object
# doi                    20 non-null object
# entry_date             20 non-null object
# format                 20 non-null object
# journal_issue          20 non-null object
# journal_name           20 non-null object
# journal_volume         20 non-null object
# language               20 non-null object
# links                  20 non-null object
# osti_id                20 non-null object
# product_type           20 non-null object
# publication_date       20 non-null object
# publisher              20 non-null object
# report_number          20 non-null object
# research_orgs          20 non-null object
# sponsor_orgs           20 non-null object
# subjects               20 non-null object
# title                  20 non-null object
# dtypes: object(24)
# memory usage: 3.8+ KB

# %%
#Provide some basic info about missing values
missing = pd.DataFrame(df.isnull().sum()).rename(columns = {0: 'total missing'})
missing['percent missing'] = round(missing['total missing'] / len(df),2)
missing.sort_values('total missing', ascending = False)
# Out:
#                      total missing  percent missing
# article_type                    15             0.75
# authors                          0             0.00
# subjects                         0             0.00
# sponsor_orgs                     0             0.00
# research_orgs                    0             0.00
# report_number                    0             0.00
# publisher                        0             0.00
# publication_date                 0             0.00
# product_type                     0             0.00
# osti_id                          0             0.00
# links                            0             0.00
# language                         0             0.00
# journal_volume                   0             0.00
# journal_name                     0             0.00
# journal_issue                    0             0.00
# format                           0             0.00
# entry_date                       0             0.00
# doi                              0             0.00
# doe_contract_number              0             0.00
# description                      0             0.00
# country_publication              0             0.00
# contributing_org                 0             0.00
# availability                     0             0.00
# title                            0             0.00

# %%
#Forcing a column (sponsor_orgs) that can have multiple values per row (by way of a list) to be melted into 
    # a database-like setup, with a new row for every unique list value in that original column

df['sponsor_orgs'].apply(pd.Series)\
    .merge(df, right_index = True, left_index = True)\
    .drop(["sponsor_orgs"], axis = 1) \
    .melt(id_vars = df.drop('sponsor_orgs', axis = 1).columns.values, value_name = "sponsor_org") \
    .drop("variable", axis = 1) \
    .dropna(subset = ['sponsor_org'])['sponsor_org'].value_counts()
# Out:
# USDOE Office of Energy Efficiency and Renewable Energy (EERE), Solar Energy Technologies Office (EE-4S)                        8
# USDOE Office of Energy Efficiency and Renewable Energy (EERE), Fuel Cell Technologies Office (EE-3F)                           4
# USDOE Office of Energy Efficiency and Renewable Energy (EERE), Vehicle Technologies Office (EE-3V)                             3
# USDOE Office of Energy Efficiency and Renewable Energy (EERE), Wind and Water Technologies Office (EE-4W)                      2
# USDOE Office of Energy Efficiency and Renewable Energy (EERE), Solar Energy Technologies Office (EE-4S), SunShot Initiative    1
# USDOE Office of Energy Efficiency and Renewable Energy (EERE), Weatherization and Intergovernmental Programs Office (EE-5W)    1
# USDOE Office of Energy Efficiency and Renewable Energy (EERE), Building Technologies Office (EE-5B)                            1
# USDOE Office of Energy Efficiency and Renewable Energy (EERE), Bioenergy Technologies Office (EE-3B)                           1
# Name: sponsor_org, dtype: int64
